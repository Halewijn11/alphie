# %%
import utils 
import importlib
# import seaborn as sns
import pandas as pd
import os
import sys
# import matplotlib.pyplot as plt
# utils_dir = os.path.abspath("../")
# sys.path.append(utils_dir)
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from 'c:\\Users\\halewijnvanden\\OneDrive - Delft University of Technology\\Documents\\year1\\side_projects\\alphie\\streamlit_app\\utils.py'>

# %%
import af_analysis
my_data = af_analysis.Data('./folds_2026_02_02_16_03/pa3mcp_6mer/', format = 'AF3_webserver')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 2
#       1 import af_analysis
# ----> 2 my_data = af_analysis.Data('./folds_2026_02_02_16_03/pa3mcp_6mer/', format = 'pdb')
#
# File c:\Users\halewijnvanden\AppData\Local\anaconda3\envs\alphie_env\lib\site-packages\af_analysis\data.py:117, in Data.__init__(self, directory, data_dict, csv, verbose, format)
#     114 """ """
#     116 if directory is not None:
# --> 117     self.read_directory(directory, verbose=verbose, format=format)
#     118 elif csv is not None:
#     119     self.format = "csv"
#
# File c:\Users\halewijnvanden\AppData\Local\anaconda3\envs\alphie_env\lib\site-packages\af_analysis\data.py:203, in Data.read_directory(self, directory, keep_recycles, verbose, format)
#     201     self.df = default.read_dir(directory)
#     202     self.df["format"] = "default"
# ...

# %%
try:
    my_data = af_analysis.Data('./folds_2026_02_02_16_03/binder_target/', format='default')
except Exception as e:
    print(f"Fallback error: {e}")
    # Plan B: Manual directory read if you just want the PDBs/scores
    my_data = af_analysis.Data('./folds_2026_02_02_16_03/binder_target/')
# Out:
# Fallback error: 'query'
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 try:
# ----> 2     my_data = af_analysis.Data('./folds_2026_02_02_16_03/binder_target/', format='default')
#       3 except Exception as e:
#
# File c:\Users\halewijnvanden\AppData\Local\anaconda3\envs\alphie_env\lib\site-packages\af_analysis\data.py:117, in Data.__init__(self, directory, data_dict, csv, verbose, format)
#     116 if directory is not None:
# --> 117     self.read_directory(directory, verbose=verbose, format=format)
#     118 elif csv is not None:
#
# File c:\Users\halewijnvanden\AppData\Local\anaconda3\envs\alphie_env\lib\site-packages\af_analysis\data.py:203, in Data.read_directory(self, directory, keep_recycles, verbose, format)
#     202     self.df["format"] = "default"
# --> 203     self.add_json(verbose=verbose)
#     205 self.set_chain_length()
#
# ...

# %%
import os
import pandas as pd
import af_analysis

path = './folds_2026_02_02_16_03/binder_target/'

# 1. Create a manual manifest of your files
data_list = []
for f in os.listdir(path):
    if f.endswith('.pdb') or f.endswith('.cif'):
        # Match "model_name.pdb" with "model_name_summary_confidences_0.json" 
        # (or whatever naming AF3 gave you)
        base_name = f.rsplit('.', 1)[0]
        data_list.append({
            'name': base_name,
            'pdb': os.path.join(path, f),
            # You might need to adjust this matching logic based on your exact filenames
            'json': os.path.join(path, base_name + '_summary_confidences_0.json') 
        })

# 2. Force the Data object to accept our manual list
my_data = af_analysis.Data(directory=None) # Start empty
my_data.dir = path
my_data.df = pd.DataFrame(data_list)

# 3. Manually trigger the score extraction 
# This bypasses the 'query' check in the directory reader
try:
    from af_analysis.format import default
    # If this fails, we can pull scores manually from the JSONs
    print("Attempting manual score extraction...")
    # Add your own score loading logic here if needed
except Exception as e:
    print(f"Could not auto-load scores: {e}")

print("Data object initialized manually.")
# Out:
# Attempting manual score extraction...
# Data object initialized manually.

# %%
from af_analysis import analysis
analysis.pdockq(my_data)
from af_analysis import docking
# docking.LIS_pep(my_data)
docking.ipSAE(my_data)
# Out:
#   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 5
#       3 from af_analysis import docking
#       4 # docking.LIS_pep(my_data)
# ----> 5 docking.ipSAE(my_data)
#
# AttributeError: module 'af_analysis.docking' has no attribute 'ipSAE'

# %%
docking.ipTM_d0_interface_lig(my_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\halewijnvanden\AppData\Local\anaconda3\envs\alphie_env\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'query'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[6], line 1
# ...

# %%
docking.ipSAE_lig(my_data)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\halewijnvanden\AppData\Local\anaconda3\envs\alphie_env\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'query'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 1
# ...

# %%
# import af_analysis
# my_data = af_analysis.Data('MY_AF_RESULTS_DIR')
af_analysis.__version__
# Out:
# '0.1.5'

# %%
# from ipsae.ipsae import calculate_ipsae # Note: sub-module names may vary
# import ipsae

# # Example usage
# results = calculate_ipsae(
#     pae_file="scores.json", 
#     structure_file="model.pdb", 
#     pae_cutoff=10, 
#     dist_cutoff=15
# )
import ipsae
# Out:
# Usage for AF2 (PDB format):
#    python ipsae.py <path_to_pae_json_file> <path_to_pdb_file> <pae_cutoff> <dist_cutoff>
#    python ipsae.py RAF1_KSR1_scores_rank_001_alphafold2_multimer_v3_model_4_seed_003.json RAF1_KSR1_unrelaxed_rank_001_alphafold2_multimer_v3_model_4_seed_003.pdb 10 15
#
# Usage for AF3 (mmCIF format):
#    python ipsae.py <path_to_pae_json_file> <path_to_mmcif_file> <pae_cutoff> <dist_cutoff>
#    python ipsae.py fold_aurka_tpx2_full_data_0.json  fold_aurka_tpx2_model_0.cif 10 15
#
# Usage for Boltz (PDB or mmCIF format):
#    python ipsae.py <path_to_pae_npz_file> <path_to_mmcif_file> <pae_cutoff> <dist_cutoff>
#    python ipsae.py <path_to_pae_npz_file> <path_to_pdb_file> <pae_cutoff> <dist_cutoff>
#    python ipsae.py pae_AURKA_TPX2_model_0.npz  AURKA_TPX2_model_0.cif 10 15
#    python ipsae.py pae_AURKA_TPX2_model_0.npz  AURKA_TPX2_model_0.pdb 10 15
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 1

# %%
os.listdir(structome_path)
# Out:
# ['fold_pa3mcp_6mer']

# %%
import importlib
importlib.reload(utils)
structome_path = './folds_2026_02_02_16_03/'
utils.get_structome_best_model_metadata(structome_path)
# Out:
#    prediction_id                    cif_filename  \
# 0  binder_target  fold_binder_target_model_0.cif
# 1    pa3mcp_6mer    fold_pa3mcp_6mer_model_0.cif
#
#                                         cif_filepath  iptm   ptm  \
# 0  ./folds_2026_02_02_16_03/binder_target/fold_bi...  0.73  0.73
# 1  ./folds_2026_02_02_16_03/pa3mcp_6mer/fold_pa3m...  0.72  0.72
#
#    ranking_score                       chain_ptm  \
# 0           0.75                    [0.92, 0.91]
# 1           0.80  [0.8, 0.8, 0.8, 0.8, 0.8, 0.8]
#
#                              chain_iptm prediction_type  \
# 0                          [0.73, 0.73]             AF3
# 1  [0.63, 0.63, 0.63, 0.63, 0.63, 0.62]             AF3
#
#                                             filepath
# 0  ./folds_2026_02_02_16_03/binder_target/fold_bi...
# 1  ./folds_2026_02_02_16_03/pa3mcp_6mer/fold_pa3m...

# %%
import importlib
importlib.reload(utils)
# utils.create_alphafold_json_files()
# Out:
# <module 'utils' from 'c:\\Users\\halewijnvanden\\OneDrive - Delft University of Technology\\Documents\\year1\\side_projects\\alphie\\streamlit_app\\utils.py'>

# %%
import importlib
importlib.reload(utils)
df = pd.read_csv('test.csv',sep=None, engine='python',encoding='utf-8-sig')

utils.create_alphafold_json_files(
    df
)

# %%
df.groupby('prediction_id')

# %%
df = pd.read_csv('test.csv',sep=None, engine='python')

print(df.columns)
df['entity_type']
# Out:
# Index(['﻿prediction_id', 'entity_type', 'sequence', 'copies'], dtype='object')
# 0    protein
# 1    protein
# Name: entity_type, dtype: object
