# %%
import utils 
import importlib
# import seaborn as sns
import pandas as pd
import os
import sys
# import matplotlib.pyplot as plt
# utils_dir = os.path.abspath("../")
# sys.path.append(utils_dir)
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from 'c:\\Users\\halewijnvanden\\OneDrive - Delft University of Technology\\Documents\\year1\\side_projects\\alphie\\streamlit_app\\utils.py'>

# %%
import importlib
importlib.reload(utils)
utils.create_alphafold_json_files()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import importlib
#       2 importlib.reload(utils)
# ----> 3 utils.create_alphafold_json_files()
#
# TypeError: create_alphafold_json_files() missing 1 required positional argument: 'df'

# %%
df = pd.read_csv('delete.csv')

melted_df = df.melt(id_vars=prediction_id_col_name, 
                value_vars=['target_seq', 'binder_seq'],
                var_name='binder_or_target', 
                value_name='sequence')
