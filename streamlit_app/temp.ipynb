# %%
import utils 
import importlib
# import seaborn as sns
import pandas as pd
import os
import sys
# import matplotlib.pyplot as plt
# utils_dir = os.path.abspath("../")
# sys.path.append(utils_dir)
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from 'c:\\Users\\halewijnvanden\\OneDrive - Delft University of Technology\\Documents\\year1\\side_projects\\alphie\\streamlit_app\\utils.py'>

# %%
os.listdir(structome_path)
# Out:
# ['fold_pa3mcp_6mer']

# %%
import importlib
importlib.reload(utils)
structome_path = './prediction/'
utils.get_structome_best_model_metadata(structome_path)
# Out:
# ./prediction/fold_pa3mcp_6mer/
# fold_pa3mcp_6mer
# []
# []
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[21], line 4
#       2 importlib.reload(utils)
#       3 structome_path = './prediction/'
# ----> 4 utils.get_structome_best_model_metadata(structome_path)
#
# File c:\Users\halewijnvanden\OneDrive - Delft University of Technology\Documents\year1\side_projects\alphie\streamlit_app\utils.py:344, in get_structome_best_model_metadata(AF_structure_repository_path, model)
#     340 print(prediction_repository)
#     343     # prediction_repository = AF_structure_repository_path + prediction_name + '/'
# --> 344 cif_filename, best_model_nr, best_iptm, best_ptm, best_ranking_score,best_chain_ptm, best_chain_iptm =get_best_AF3_model_info(prediction_repository,prediction_name, model = model)
#     345 cif_filepath_array += [prediction_repository + cif_filename]
# ...

# %%
import importlib
importlib.reload(utils)
# utils.create_alphafold_json_files()
# Out:
# <module 'utils' from 'c:\\Users\\halewijnvanden\\OneDrive - Delft University of Technology\\Documents\\year1\\side_projects\\alphie\\streamlit_app\\utils.py'>

# %%
import importlib
importlib.reload(utils)
df = pd.read_csv('test.csv',sep=None, engine='python',encoding='utf-8-sig')

utils.create_alphafold_json_files(
    df
)

# %%
df.groupby('prediction_id')

# %%
df = pd.read_csv('test.csv',sep=None, engine='python')

print(df.columns)
df['entity_type']
# Out:
# Index(['﻿prediction_id', 'entity_type', 'sequence', 'copies'], dtype='object')
# 0    protein
# 1    protein
# Name: entity_type, dtype: object
